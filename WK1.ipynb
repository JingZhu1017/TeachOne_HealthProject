# %% [raw]
# """
# Student Name: Jing Zhu
# Project: HAP725_W1Q2_UsingPythontoPlot
#
# """

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
jzdata = pd.read_csv('C:/Users/zhuji/Downloads/HAP725/WK1/Data Q2 Introduction.csv')

# %%
print(jzdata)
# Out:
#     Time  Observed value  Upper limit  Lower Limit
# 0      1              30         52.5         12.5
# 1      2               0         52.5         12.5
# 2      3              25         52.5         12.5
# 3      4              30         52.5         12.5
# 4      5              35         52.5         12.5
# 5      6              40         52.5         12.5
# 6      7              50         52.5         12.5
# 7      8              45         52.5         12.5
# 8      9              31         52.5         12.5
# 9     10              20         52.5         12.5
# 10    11              40         52.5         12.5
# 11    12              60         52.5         12.5
# 12    13              45         52.5         12.5
# 13    14              60         52.5         12.5
# 14    15              45         52.5         12.5
# 15    16              32         52.5         12.5
# 16    17              50         52.5         12.5
# ...

# %%
jzdata.plot(x = 'Time', y = 'Observed value', kind = 'line', marker = 'o')
plt.xlabel('Time')
plt.ylabel('Observed Value')
plt.title('Using Python to Plot', color='black', fontsize=15)
plt.hlines(y = 52.5, xmin = 1, xmax = 7, color = 'r', label = 'pre-intervention')
plt.hlines(y = 12.5, xmin = 1, xmax = 7, color = 'r')
plt.hlines(y = 52.5, xmin = 9, xmax = 18, color = 'r', linestyles = 'dashed', label = 'post-intervention')
plt.hlines(y = 12.5, xmin = 9, xmax = 18, color = 'r', linestyles = 'dashed')
plt.xticks(jzdata['Time'],jzdata['Time'])
plt.legend(bbox_to_anchor=(1.05,1), loc = 'upper left', borderaxespad = 0.)
plt.show()
